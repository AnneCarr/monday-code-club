# %%
import requests
import json
import pandas as pd
import lxml

# %% [markdown]
# # Recap task from last week
# **Saved here: https://github.com/AnneCarr/monday-code-club/blob/master/CodeClub-14-Aug-dict.ipynb  **
#
# - Get JSON data from an external source into a Dataframe

# %% [markdown]
# # This week
# We are going to learn how to create and use functions
#
# Have a look a this tutorial for more info on python functions
# https://www.datacamp.com/community/tutorials/functions-python-tutorial#gs.6QALerI
#
# ## First task
#
# Using the techniques learned from last week we will
#  - create functions to allow us to repeat the task of getting JSON data from external sources
#  - use a for loop to loop through the functions to append data from several sources into a dataframe
#  - group the data to learn
#   - Which petition had the most number of signatures
#   - Which constituency has the most active voters
#   - get the % of overall constituency numbers that signed a petition
#   - anyother interesting insights you can find and chart based on what we've learned so far

# %% [markdown]
# We are going to create a function using two different techniques
#
# In this one we are going
#  - to pass the URL for the JSON data into the function
#  - build a dataframe from the specific set of JSON data we want
#  - add a column for the name of the petition
#  - return the completed dataframe

# %%
# list of petition urls we are going to use
petitions_list = ['https://petition.parliament.uk/petitions/175433.json',
                'https://petition.parliament.uk/petitions/166847.json',
                'https://petition.parliament.uk/petitions/165672.json',
                  'https://petition.parliament.uk/petitions/187027.json']

# %% [markdown]
# We name the function get_petitions_url
#
# We will pass one variable into the function - in this case the URL for the json data we will be using

# %%
def get_petitions_url(url):
#     get the JSON data using requests and set it as a JSON object variable
    petitions_data = requests.get(url) 
    petitions_dict = petitions_data.json()
#     Navigate to the data we need and create a dataframe on the data
    const = pd.DataFrame.from_dict(petitions_dict['data']['attributes']['signatures_by_constituency'])
#     add a new column for the name of the petition
    const['petition_name'] = petitions_dict['data']['attributes']['action']
#     the output of the function is the completed dataframe
    return const

# %% [markdown]
# We use this for loop to loop through the list of petition urls
#
# We then call the get_petition_url function passing in the url from the list
#
# On each loop through on the for loop we append the petitions_df with the data collected from the function

# %%
petitions_df = pd.DataFrame()
for petition in petitions_list:
    df = get_petitions_url(petition)
    petitions_df = petitions_df.append(df)

petitions_df.head()
# Out:
#                      mp                       name   ons_code  \
# 0     Tommy Sheppard MP             Edinburgh East  S14000022
# 1       Deidre Brock MP  Edinburgh North and Leith  S14000023
# 2         Ian Murray MP            Edinburgh South  S14000024
# 3   Joanna Cherry QC MP       Edinburgh South West  S14000025
# 4  Christine Jardine MP             Edinburgh West  S14000026
#
#    signature_count                                      petition_name
# 0               13  Stop business rate rises before they wreck ind...
# 1               34  Stop business rate rises before they wreck ind...
# 2                7  Stop business rate rises before they wreck ind...
# 3               12  Stop business rate rises before they wreck ind...
# 4               10  Stop business rate rises before they wreck ind...

# %% [markdown]
# In this option we pass in the JSON data we need and create the dataframe directly from the data
#
# We will pass in two variables in this case
#  - one for the constituency data
#  - one for the name of the petition
#
# We return the completed dataframe

# %%
def get_petitions_dict(const_data,name_data):
    const_df = pd.DataFrame.from_dict(const_data)
    const_df['petition_name'] = name_data
    
    return const_df

# %% [markdown]
# In this for loop we are looping through the petitions_list as before but in this case we are setting a variable with the specific data we need to build the dataframe prior to calling the function
#
# The JSON data object is passed into the function and called 'constitucany' - this is used to build the dataframe in the function
# The name of the petition is stored in 'name_petition' and also passed into the function
#
# On each loop of the for loop the dataframe object is returned an appended to petitions_df

# %%
petitions_df = pd.DataFrame()

for petition in petitions_list:
    petitions_data = requests.get(petition)
    petitions_dict = petitions_data.json()
    constituancy = pd.DataFrame.from_dict(petitions_dict['data']['attributes']['signatures_by_constituency'])
    name_petition = petitions_dict['data']['attributes']['action']
    df = get_petitions_dict(constituancy,name_petition)
    petitions_df = petitions_df.append(df)

petitions_df.head()
# Out:
#                      mp                       name   ons_code  \
# 0     Tommy Sheppard MP             Edinburgh East  S14000022
# 1       Deidre Brock MP  Edinburgh North and Leith  S14000023
# 2         Ian Murray MP            Edinburgh South  S14000024
# 3   Joanna Cherry QC MP       Edinburgh South West  S14000025
# 4  Christine Jardine MP             Edinburgh West  S14000026
#
#    signature_count                                      petition_name
# 0               13  Stop business rate rises before they wreck ind...
# 1               34  Stop business rate rises before they wreck ind...
# 2                7  Stop business rate rises before they wreck ind...
# 3               12  Stop business rate rises before they wreck ind...
# 4               10  Stop business rate rises before they wreck ind...

# %% [markdown]
# As last week we will add the county, electorate population and region data to our completed dataframe

# %%
counties = requests.get("https://en.wikipedia.org/wiki/List_of_United_Kingdom_Parliament_constituencies").text

# %%
lsDf = pd.read_html(counties)
df = lsDf[1]
df.head()
# Out:
#                           0                1                2  \
# 0              Constituency  Electorate 2000  Electorate 2010
# 1                 Aldershot            66499            71908
# 2       Aldridge-Brownhills            58695            59506
# 3  Altrincham and Sale West            69605            72008
# 4              Amber Valley            66406            69538
#
#                  3                                                  4  \
# 0  Electorate 2017  Largest ceremonial county or council area (Sco...
# 1            76205                                          Hampshire
# 2            60363                                      West Midlands
# 3            73220                                 Greater Manchester
# 4            68065                                         Derbyshire
#
#                    5              6
# 0  Country of the UK         Region
# 1            England     South East
# 2            England  West Midlands
# 3            England     North West
# 4            England  East Midlands

# %%
new_header = df.iloc[0]

# %% [markdown]
# Get the rest of the data, less the header row

# %%
df = df[1:] #take the data less the header row

# %% [markdown]
# Rename the columns with your header row

# %%
df = df.rename(columns = new_header)

# %% [markdown]
# Now we can use it like a normal dataframe

# %%
df.head()
# Out:
#                Constituency Electorate 2000 Electorate 2010 Electorate 2017  \
# 1                 Aldershot           66499           71908           76205
# 2       Aldridge-Brownhills           58695           59506           60363
# 3  Altrincham and Sale West           69605           72008           73220
# 4              Amber Valley           66406           69538           68065
# 5   Arundel and South Downs           71203           76697           80766
#
#   Largest ceremonial county or council area (Scotland) Country of the UK  \
# 1                                          Hampshire             England
# 2                                      West Midlands             England
# 3                                 Greater Manchester             England
# 4                                         Derbyshire             England
# 5                                        West Sussex             England
#
#           Region
# 1     South East
# 2  West Midlands
# 3     North West
# 4  East Midlands
# 5     South East

# %%
petitions_df.head()
# Out:
#                      mp                       name   ons_code  \
# 0     Tommy Sheppard MP             Edinburgh East  S14000022
# 1       Deidre Brock MP  Edinburgh North and Leith  S14000023
# 2         Ian Murray MP            Edinburgh South  S14000024
# 3   Joanna Cherry QC MP       Edinburgh South West  S14000025
# 4  Christine Jardine MP             Edinburgh West  S14000026
#
#    signature_count                                      petition_name
# 0               13  Stop business rate rises before they wreck ind...
# 1               34  Stop business rate rises before they wreck ind...
# 2                7  Stop business rate rises before they wreck ind...
# 3               12  Stop business rate rises before they wreck ind...
# 4               10  Stop business rate rises before they wreck ind...

# %%
petitions_df = petitions_df.rename(index=str, columns={"name": "Constituency"})
petitions_df.head()
# Out:
#                      mp               Constituency   ons_code  \
# 0     Tommy Sheppard MP             Edinburgh East  S14000022
# 1       Deidre Brock MP  Edinburgh North and Leith  S14000023
# 2         Ian Murray MP            Edinburgh South  S14000024
# 3   Joanna Cherry QC MP       Edinburgh South West  S14000025
# 4  Christine Jardine MP             Edinburgh West  S14000026
#
#    signature_count                                      petition_name
# 0               13  Stop business rate rises before they wreck ind...
# 1               34  Stop business rate rises before they wreck ind...
# 2                7  Stop business rate rises before they wreck ind...
# 3               12  Stop business rate rises before they wreck ind...
# 4               10  Stop business rate rises before they wreck ind...

# %% [markdown]
# left join

# %%
dfRegion = pd.merge(petitions_df, df, how="left", on="Constituency")
dfRegion
# Out:
#                                  mp  \
# 0                 Tommy Sheppard MP
# 1                   Deidre Brock MP
# 2                     Ian Murray MP
# 3               Joanna Cherry QC MP
# 4              Christine Jardine MP
# 5                   David Duguid MP
# 6                Alison Thewliss MP
# 7                  Patrick Grady MP
# 8              Mr Paul J Sweeney MP
# 9       Stewart Malcolm McDonald MP
# 10                   Colin Clark MP
# 11               Kirsty Blackman MP
# 12                   Drew Hendry MP
# 13                    Alan Brown MP
# 14                  Lesley Laird MP
# 15                    Martyn Day MP
# 16                Hannah Bardell MP
# 17               Danielle Rowley MP
# 18                  Ross Thomson MP
# 19                  Douglas Ross MP
# 20                Marion Fellows MP
# 21               Stephen Gethins MP
# 22                   John Lamont MP
# 23                   Luke Graham MP
# 24    Rt Hon Alistair Carmichael MP
# 25                Gavin Newlands MP
# 26                  Mhairi Black MP
# 27                  Pete Wishart MP
# 28          Rt Hon Ian Blackford MP
# 29                 Gerard Killen MP
# ...                             ...
# 2519               Eleanor Smith MP
# 2520             Mr Robin Walker MP
# 2521                  Sue Hayman MP
# 2522              Barbara Keeley MP
# 2523         Sir Peter Bottomley MP
# 2524                Ian C. Lucas MP
# 2525              Mr Steve Baker MP
# 2526         Rt Hon Ben  Wallace MP
# 2527                Mark Garnier MP
# 2528                   Mike Kane MP
# 2529              Mr Marcus Fysh MP
# 2530                 Albert Owen MP
# 2531             Rachael Maskell MP
# 2532               Julian Sturdy MP
# 2533                 Jamie Stone MP
# 2534               Kirstene Hair MP
# 2535        Dr Philippa Whitford MP
# 2536              Brendan O'Hara MP
# 2537                Hugh Gaffney MP
# 2538          Stuart C. McDonald MP
# 2539             Mr Alister Jack MP
# 2540        Rt Hon David Mundell MP
# 2541               Stewart Hosie MP
# 2542                   Chris Law MP
# 2543             Douglas Chapman MP
# 2544                  Jo Swinson MP
# 2545             Dr Lisa Cameron MP
# 2546                  Bill Grant MP
# 2547            Martin Whitfield MP
# 2548              Paul Masterton MP
#
#                                      Constituency   ons_code  signature_count  \
# 0                                  Edinburgh East  S14000022               13
# 1                       Edinburgh North and Leith  S14000023               34
# 2                                 Edinburgh South  S14000024                7
# 3                            Edinburgh South West  S14000025               12
# 4                                  Edinburgh West  S14000026               10
# 5                                Banff and Buchan  S14000007                2
# 6                                 Glasgow Central  S14000029                5
# 7                                   Glasgow North  S14000031                2
# 8                              Glasgow North East  S14000032                1
# 9                                   Glasgow South  S14000034                5
# 10                                         Gordon  S14000037                1
# 11                                 Aberdeen North  S14000001                1
# 12      Inverness, Nairn, Badenoch and Strathspey  S14000039                1
# 13                         Kilmarnock and Loudoun  S14000040                1
# 14                      Kirkcaldy and Cowdenbeath  S14000041                6
# 15                    Linlithgow and East Falkirk  S14000043                2
# 16                                     Livingston  S14000044                1
# 17                                     Midlothian  S14000045                6
# 18                                 Aberdeen South  S14000002                4
# 19                                          Moray  S14000046                2
# 20                          Motherwell and Wishaw  S14000047                1
# 21                                North East Fife  S14000049               12
# 22             Berwickshire, Roxburgh and Selkirk  S14000008                3
# 23                     Ochil and South Perthshire  S14000050                3
# 24                            Orkney and Shetland  S14000051                1
# 25                 Paisley and Renfrewshire North  S14000052                1
# 26                 Paisley and Renfrewshire South  S14000053                1
# 27                     Perth and North Perthshire  S14000054                8
# 28                        Ross, Skye and Lochaber  S14000055                5
# 29                   Rutherglen and Hamilton West  S14000056                3
# ...                                           ...        ...              ...
# 2519                     Wolverhampton South West  E14001051                5
# 2520                                    Worcester  E14001052               15
# 2521                                   Workington  E14001053               12
# 2522                     Worsley and Eccles South  E14001054               33
# 2523                                Worthing West  E14001055                3
# 2524                                      Wrexham  W07000044                3
# 2525                                      Wycombe  E14001056               10
# 2526                       Wyre and Preston North  E14001057               12
# 2527                                  Wyre Forest  E14001058                7
# 2528                    Wythenshawe and Sale East  E14001059               25
# 2529                                       Yeovil  E14001060               26
# 2530                                     Ynys Môn  W07000041                8
# 2531                                 York Central  E14001061               23
# 2532                                   York Outer  E14001062               11
# 2533        Caithness, Sutherland and Easter Ross  S14000009               15
# 2534                                        Angus  S14000004               18
# 2535                             Central Ayrshire  S14000010               14
# 2536                              Argyll and Bute  S14000005                8
# 2537           Coatbridge, Chryston and Bellshill  S14000011               29
# 2538  Cumbernauld, Kilsyth and Kirkintilloch East  S14000012               22
# 2539                        Dumfries and Galloway  S14000013               15
# 2540      Dumfriesshire, Clydesdale and Tweeddale  S14000014               11
# 2541                                  Dundee East  S14000015               12
# 2542                                  Dundee West  S14000016               17
# 2543                    Dunfermline and West Fife  S14000017               20
# 2544                          East Dunbartonshire  S14000018                8
# 2545     East Kilbride, Strathaven and Lesmahagow  S14000019               31
# 2546                     Ayr, Carrick and Cumnock  S14000006               24
# 2547                                 East Lothian  S14000020               14
# 2548                            East Renfrewshire  S14000021               17
#
#                                           petition_name Electorate 2000  \
# 0     Stop business rate rises before they wreck ind...           74505
# 1     Stop business rate rises before they wreck ind...           74762
# 2     Stop business rate rises before they wreck ind...           68884
# 3     Stop business rate rises before they wreck ind...           75787
# 4     Stop business rate rises before they wreck ind...           70603
# 5     Stop business rate rises before they wreck ind...           65970
# 6     Stop business rate rises before they wreck ind...           70378
# 7     Stop business rate rises before they wreck ind...           63729
# 8     Stop business rate rises before they wreck ind...           70899
# 9     Stop business rate rises before they wreck ind...           74482
# 10    Stop business rate rises before they wreck ind...           69631
# 11    Stop business rate rises before they wreck ind...           69622
# 12    Stop business rate rises before they wreck ind...           67790
# 13    Stop business rate rises before they wreck ind...           72922
# 14    Stop business rate rises before they wreck ind...           74163
# 15    Stop business rate rises before they wreck ind...           78675
# 16    Stop business rate rises before they wreck ind...           76299
# 17    Stop business rate rises before they wreck ind...           62787
# 18    Stop business rate rises before they wreck ind...           69332
# 19    Stop business rate rises before they wreck ind...           63959
# 20    Stop business rate rises before they wreck ind...           67499
# 21    Stop business rate rises before they wreck ind...           64813
# 22    Stop business rate rises before they wreck ind...           72430
# 23    Stop business rate rises before they wreck ind...           71738
# 24    Stop business rate rises before they wreck ind...           32181
# 25    Stop business rate rises before they wreck ind...           68642
# 26    Stop business rate rises before they wreck ind...           68038
# 27    Stop business rate rises before they wreck ind...           70718
# 28    Stop business rate rises before they wreck ind...           49544
# 29    Stop business rate rises before they wreck ind...           75370
# ...                                                 ...             ...
# 2519  Amend the Births and Deaths Registration Act 1...           63641
# 2520  Amend the Births and Deaths Registration Act 1...           71601
# 2521  Amend the Births and Deaths Registration Act 1...           61369
# 2522  Amend the Births and Deaths Registration Act 1...           72554
# 2523  Amend the Births and Deaths Registration Act 1...           72585
# 2524  Amend the Births and Deaths Registration Act 1...           50980
# 2525  Amend the Births and Deaths Registration Act 1...           71997
# 2526  Amend the Births and Deaths Registration Act 1...           68812
# 2527  Amend the Births and Deaths Registration Act 1...           75563
# 2528  Amend the Births and Deaths Registration Act 1...           72093
# 2529  Amend the Births and Deaths Registration Act 1...           77049
# 2530  Amend the Births and Deaths Registration Act 1...           49831
# 2531  Amend the Births and Deaths Registration Act 1...           71160
# 2532  Amend the Births and Deaths Registration Act 1...           71613
# 2533  Amend the Births and Deaths Registration Act 1...           46533
# 2534  Amend the Births and Deaths Registration Act 1...           64591
# 2535  Amend the Births and Deaths Registration Act 1...           69161
# 2536  Amend the Births and Deaths Registration Act 1...           69571
# 2537  Amend the Births and Deaths Registration Act 1...           67647
# 2538  Amend the Births and Deaths Registration Act 1...           67802
# 2539  Amend the Births and Deaths Registration Act 1...           75316
# 2540  Amend the Births and Deaths Registration Act 1...           65137
# 2541  Amend the Births and Deaths Registration Act 1...           65059
# 2542  Amend the Births and Deaths Registration Act 1...           67751
# 2543  Amend the Births and Deaths Registration Act 1...           70373
# 2544  Amend the Births and Deaths Registration Act 1...           66724
# 2545  Amend the Births and Deaths Registration Act 1...           77257
# 2546  Amend the Births and Deaths Registration Act 1...           74159
# 2547  Amend the Births and Deaths Registration Act 1...           71288
# 2548  Amend the Births and Deaths Registration Act 1...           69249
#
#      Electorate 2010 Electorate 2017  \
# 0              60594           67141
# 1              69580           80910
# 2              59285           65801
# 3              66262           72149
# 4              65526           71717
# 5              65183           68609
# 6              67521           70945
# 7              54620           60169
# 8              64171           66678
# 9              69122           74051
# 10             74394           79393
# 11             64753           67745
# 12             72764           77628
# 13             75001           75250
# 14             74247           75941
# 15             81756           86955
# 16             76580           82373
# 17             61986           67875
# 18             64330           68056
# 19             66726           71685
# 20             66949           70283
# 21             63349           62003
# 22             74115           74214
# 23             75848           77370
# 24             33755           34552
# 25             65847           66206
# 26             63268           61281
# 27             73064           72459
# 28             52064           54169
# 29             77729           82830
# ...              ...             ...
# 2519           59846           60368
# 2520           73960           72461
# 2521           59361           58615
# 2522           73409           72177
# 2523           74468           75617
# 2524           53733           50992
# 2525           73750           76371
# 2526           71612           70637
# 2527           77800           77407
# 2528           75602           75994
# 2529           82771           82447
# 2530           49721           49939
# 2531           75656           75351
# 2532           75125           78561
# 2533           47572           47558
# 2534           64178           65792
# 2535           69243           70021
# 2536           67692           68875
# 2537           70537           73894
# 2538           65317           67088
# 2539           74414           75249
# 2540           67066           68483
# 2541           65702           67822
# 2542           63065           65927
# 2543           74621           78037
# 2544           64186           66966
# 2545           77985           83205
# 2546           73708           72995
# 2547           74320           79481
# 2548           68117           69982
#
#      Largest ceremonial county or council area (Scotland) Country of the UK  \
# 0                                     City of Edinburgh            Scotland
# 1                                     City of Edinburgh            Scotland
# 2                                     City of Edinburgh            Scotland
# 3                                     City of Edinburgh            Scotland
# 4                                     City of Edinburgh            Scotland
# 5                                         Aberdeenshire            Scotland
# 6                                          Glasgow City            Scotland
# 7                                          Glasgow City            Scotland
# 8                                          Glasgow City            Scotland
# 9                                          Glasgow City            Scotland
# 10                                        Aberdeenshire            Scotland
# 11                                        Aberdeen City            Scotland
# 12                                             Highland            Scotland
# 13                                        East Ayrshire            Scotland
# 14                                                 Fife            Scotland
# 15                             West Lothian and Falkirk            Scotland
# 16                                         West Lothian            Scotland
# 17                                           Midlothian            Scotland
# 18                                        Aberdeen City            Scotland
# 19                                                Moray            Scotland
# 20                                    North Lanarkshire            Scotland
# 21                                                 Fife            Scotland
# 22                                     Scottish Borders            Scotland
# 23               Clackmannanshire and Perth and Kinross            Scotland
# 24                  Orkney Islands and Shetland Islands            Scotland
# 25                                         Renfrewshire            Scotland
# 26                                         Renfrewshire            Scotland
# 27                                    Perth and Kinross            Scotland
# 28                                             Highland            Scotland
# 29                                    South Lanarkshire            Scotland
# ...                                                 ...                 ...
# 2519                                      West Midlands             England
# 2520                                     Worcestershire             England
# 2521                                            Cumbria             England
# 2522                                 Greater Manchester             England
# 2523                                        West Sussex             England
# 2524                                            Wrexham               Wales
# 2525                                    Buckinghamshire             England
# 2526                                         Lancashire             England
# 2527                                     Worcestershire             England
# 2528                                 Greater Manchester             England
# 2529                                           Somerset             England
# 2530                                   Isle of Anglesey               Wales
# 2531                                    North Yorkshire             England
# 2532                                    North Yorkshire             England
# 2533                                           Highland            Scotland
# 2534                                              Angus            Scotland
# 2535                  North Ayrshire and South Ayrshire            Scotland
# 2536                                    Argyll and Bute            Scotland
# 2537                                  North Lanarkshire            Scotland
# 2538          East Dunbartonshire and North Lanarkshire            Scotland
# 2539                              Dumfries and Galloway            Scotland
# 2540  Dumfries and Galloway, Scottish Borders and So...            Scotland
# 2541                              Angus and Dundee City            Scotland
# 2542                              Angus and Dundee City            Scotland
# 2543                                               Fife            Scotland
# 2544                                East Dunbartonshire            Scotland
# 2545                                  South Lanarkshire            Scotland
# 2546                   East Ayrshire and South Ayrshire            Scotland
# 2547                                       East Lothian            Scotland
# 2548                                  East Renfrewshire            Scotland
#
#                       Region
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# ...                      ...
# 2519           West Midlands
# 2520           West Midlands
# 2521              North West
# 2522              North West
# 2523              South East
# 2524                     NaN
# 2525              South East
# 2526              North West
# 2527           West Midlands
# 2528              North West
# 2529              South West
# 2530                     NaN
# 2531  Yorkshire & the Humber
# 2532  Yorkshire & the Humber
# 2533                     NaN
# 2534                     NaN
# 2535                     NaN
# 2536                     NaN
# 2537                     NaN
# 2538                     NaN
# 2539                     NaN
# 2540                     NaN
# 2541                     NaN
# 2542                     NaN
# 2543                     NaN
# 2544                     NaN
# 2545                     NaN
# 2546                     NaN
# 2547                     NaN
# 2548                     NaN
#
# [2549 rows x 11 columns]

# %% [markdown]
# From the resulting dataframe find:
#  - which petition had the highest number of signatures?
#  - which constituancy is most likely to sign a petition?
#  - create a bar chart with the
