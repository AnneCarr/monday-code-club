# %%
from twython import Twython

# %% [markdown]
# APP_KEP is comsumer key - api key
# APP_SECRET is consumer secret an

# %%
APP_KEY = 'G9gsmmCEgoL5Ja2IUVetEiE8w'
APP_SECRET = 'LcWh4FrdlrXM1X3PJEv9Z7mxO0hJjzNAvttoENGOxle4Xqbk3A'
twitter = Twython(APP_KEY, APP_SECRET, oauth_version=2)
ACCESS_TOKEN = twitter.obtain_access_token()

# %%
print(ACCESS_TOKEN)
# Out:
# AAAAAAAAAAAAAAAAAAAAAOiw2AAAAAAAv975fTxwbyP4mG2rcEVuIwNysvs%3DjIXdEhlyq9bTmvPa6TsJmGnzLjgP75cGA3MwptdCt8b7t3Iabp

# %%
APP_KEY = 'G9gsmmCEgoL5Ja2IUVetEiE8w'
ACCESS_TOKEN = 'AAAAAAAAAAAAAAAAAAAAAOiw2AAAAAAAv975fTxwbyP4mG2rcEVuIwNysvs%3DjIXdEhlyq9bTmvPa6TsJmGnzLjgP75cGA3MwptdCt8b7t3Iabp'   #COPY AND PASTE FROM OUTPUT FROM ABOVE COMMAND
twitter = Twython(APP_KEY, access_token=ACCESS_TOKEN)

# %%
twitter.get_application_rate_limit_status()['resources']['search']
# Out:
# {'/search/tweets': {'limit': 450, 'remaining': 446, 'reset': 1505724421}}

# %%
twitter = Twython(APP_KEY, access_token=ACCESS_TOKEN)

# %%
twitter.search(q='#LocalGovCamp')
# Out:
# {'search_metadata': {'completed_in': 0.071,
#   'count': 15,
#   'max_id': 909695386377445377,
#   'max_id_str': '909695386377445377',
#   'next_results': '?max_id=909524869188063231&q=%23LocalGovCamp&include_entities=1',
#   'query': '%23LocalGovCamp',
#   'refresh_url': '?since_id=909695386377445377&q=%23LocalGovCamp&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Sep 18 08:27:36 +0000 2017',
#    'entities': {'hashtags': [{'indices': [22, 30], 'text': 'BTW2017'},
#      {'indices': [48, 55], 'text': 'Brexit'},
#      {'indices': [62, 75], 'text': 'localgovcamp'},
#      {'indices': [126, 134], 'text': 'dataviz'}],
#     'symbols': [],
#     'urls': [{'display_url': 'bit.ly/2xK6so5',
#       'expanded_url': 'http://bit.ly/2xK6so5',
#       'indices': [102, 125],
#       'url': 'https://t.co/GMPfJ9Lebr'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 909695386377445377,
#    'id_str': '909695386377445377',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': "Today's links: Wales, #BTW2017, infrastructure, #Brexit, NHS, #localgovcamp, Barnsleyball, the bubble https://t.co/GMPfJ9Lebr #dataviz",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jul 02 21:39:49 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Daily links on data viz, data journalism, open data and open government. Email sign up: http://t.co/bREy6Wqg3f. Run by @GavinFreeguard.',
#     'entities': {'description': {'urls': [{'display_url': 'eepurl.com/4mY7H',
#         'expanded_url': 'http://eepurl.com/4mY7H',
#         'indices': [88, 110],
#         'url': 'http://t.co/bREy6Wqg3f'}]},
#      'url': {'urls': [{'display_url': 'warninggraphiccontent.tumblr.com',
#         'expanded_url': 'http://warninggraphiccontent.tumblr.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/P7kDZgpfMn'}]}},
#     'favourites_count': 9,
#     'follow_request_sent': None,
#     'followers_count': 435,
#     'following': None,
#     'friends_count': 180,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2600485038,
#     'id_str': '2600485038',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 172,
#     'location': 'London',
#     'name': '/!\\ Graphic Content',
#     'notifications': None,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/484456576095232000/3VauMu7K.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/484456576095232000/3VauMu7K.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2600485038/1411914919',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/516234816035909632/d8YxHO-R_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/516234816035909632/d8YxHO-R_normal.png',
#     'profile_link_color': 'FF0000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'WarningGraphicC',
#     'statuses_count': 2387,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/P7kDZgpfMn',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Sep 18 08:27:19 +0000 2017',
#    'entities': {'hashtags': [{'indices': [16, 29], 'text': 'localgovcamp'}],
#     'symbols': [],
#     'urls': [{'display_url': 'philrumens.blogspot.co.uk/2017/09/localg…',
#       'expanded_url': 'http://philrumens.blogspot.co.uk/2017/09/localgovcamp-unconference-2017-turning.html',
#       'indices': [78, 101],
#       'url': 'https://t.co/JBuOGANy7f'}],
#     'user_mentions': [{'id': 51696620,
#       'id_str': '51696620',
#       'indices': [3, 14],
#       'name': 'Phil Rumens',
#       'screen_name': 'PhilRumens'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 909695315086839808,
#    'id_str': '909695315086839808',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 8,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sun Sep 17 12:49:24 +0000 2017',
#     'entities': {'hashtags': [{'indices': [0, 13], 'text': 'localgovcamp'}],
#      'symbols': [],
#      'urls': [{'display_url': 'philrumens.blogspot.co.uk/2017/09/localg…',
#        'expanded_url': 'http://philrumens.blogspot.co.uk/2017/09/localgovcamp-unconference-2017-turning.html',
#        'indices': [62, 85],
#        'url': 'https://t.co/JBuOGANy7f'}],
#      'user_mentions': []},
#     'favorite_count': 10,
#     'favorited': False,
#     'geo': None,
#     'id': 909398883322793984,
#     'id_str': '909398883322793984',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 8,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': '#localgovcamp Unconference 2017 - Turning words into actions: https://t.co/JBuOGANy7f',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sun Jun 28 10:06:45 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '#localgov Digital Services Manager and #digitaltransformation Lead. Co-Chair of @LocalGovDigital. Lead for @LGMakers. @LocalGovCamp maker. @CodeClub volunteer.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'philrumens.blogspot.com',
#          'expanded_url': 'http://philrumens.blogspot.com/',
#          'indices': [0, 22],
#          'url': 'http://t.co/seOWIUKwFq'}]}},
#      'favourites_count': 682,
#      'follow_request_sent': None,
#      'followers_count': 2353,
#      'following': None,
#      'friends_count': 925,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 51696620,
#      'id_str': '51696620',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 183,
#      'location': 'West Berkshire',
#      'name': 'Phil Rumens',
#      'notifications': None,
#      'profile_background_color': '022330',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/51696620/1442682011',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/759363547629584384/B4AxVh_N_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/759363547629584384/B4AxVh_N_normal.jpg',
#      'profile_link_color': '009966',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': '252429',
#      'profile_text_color': '666666',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'PhilRumens',
#      'statuses_count': 12412,
#      'time_zone': 'London',
#      'translator_type': 'none',
#      'url': 'http://t.co/seOWIUKwFq',
#      'utc_offset': 3600,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @PhilRumens: #localgovcamp Unconference 2017 - Turning words into actions: https://t.co/JBuOGANy7f',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Dec 13 21:26:01 +0000 2012',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'HM Government, Director Data Projects, Communities & Local Gov #opendata #datascience. Ex Data Director @gdsteam',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'gov.uk/government/org…',
#         'expanded_url': 'http://www.gov.uk/government/organisations/department-for-communities-and-local-government',
#         'indices': [0, 23],
#         'url': 'https://t.co/EWexBcdOo7'}]}},
#     'favourites_count': 1621,
#     'follow_request_sent': None,
#     'followers_count': 4906,
#     'following': None,
#     'friends_count': 2152,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1009753502,
#     'id_str': '1009753502',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 296,
#     'location': 'Whitehall, London',
#     'name': 'Paul Maltby',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1009753502/1498585676',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/810781157486919680/-yVc3RZP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/810781157486919680/-yVc3RZP_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'maltbyps',
#     'statuses_count': 4948,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': 'https://t.co/EWexBcdOo7',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Sep 18 08:23:14 +0000 2017',
#    'entities': {'hashtags': [{'indices': [39, 55], 'text': 'localgovdigital'},
#      {'indices': [56, 69], 'text': 'localgovcamp'},
#      {'indices': [73, 81], 'text': 'Bristol'}],
#     'media': [{'display_url': 'pic.twitter.com/ZRrYndAiQs',
#       'expanded_url': 'https://twitter.com/JR_InfoShareCoE/status/909694290741383168/photo/1',
#       'id': 909693890797752320,
#       'id_str': '909693890797752320',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/DJ_hxh9X0AABwui.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DJ_hxh9X0AABwui.jpg',
#       'sizes': {'large': {'h': 1537, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/ZRrYndAiQs'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/ZRrYndAiQs',
#       'expanded_url': 'https://twitter.com/JR_InfoShareCoE/status/909694290741383168/photo/1',
#       'id': 909693890797752320,
#       'id_str': '909693890797752320',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/DJ_hxh9X0AABwui.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DJ_hxh9X0AABwui.jpg',
#       'sizes': {'large': {'h': 1537, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/ZRrYndAiQs'},
#      {'display_url': 'pic.twitter.com/ZRrYndAiQs',
#       'expanded_url': 'https://twitter.com/JR_InfoShareCoE/status/909694290741383168/photo/1',
#       'id': 909693883398975490,
#       'id_str': '909693883398975490',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/DJ_hxGZXcAIXacU.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DJ_hxGZXcAIXacU.jpg',
#       'sizes': {'large': {'h': 1534, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 899, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 509, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/ZRrYndAiQs'},
#      {'display_url': 'pic.twitter.com/ZRrYndAiQs',
#       'expanded_url': 'https://twitter.com/JR_InfoShareCoE/status/909694290741383168/photo/1',
#       'id': 909693883587743744,
#       'id_str': '909693883587743744',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/DJ_hxHGX0AAPOPh.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DJ_hxHGX0AAPOPh.jpg',
#       'sizes': {'large': {'h': 1534, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 899, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 509, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/ZRrYndAiQs'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 909694290741383168,
#    'id_str': '909694290741383168',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Went for a little evening run while at #localgovdigital #localgovcamp in #Bristol. Can you tell where to? https://t.co/ZRrYndAiQs',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Apr 20 15:12:25 +0000 2017',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Digital Business Development Lead at Centre of Excellence for Information Sharing',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'informationsharing.org.uk',
#         'expanded_url': 'http://informationsharing.org.uk/',
#         'indices': [0, 23],
#         'url': 'https://t.co/Rd0LYbnrRE'}]}},
#     'favourites_count': 47,
#     'follow_request_sent': None,
#     'followers_count': 32,
#     'following': None,
#     'friends_count': 113,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 855076693593214977,
#     'id_str': '855076693593214977',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en-gb',
#     'listed_count': 0,
#     'location': 'London, England',
#     'name': 'Joel Rosen',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/855076693593214977/1492701474',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/855077891054460928/JZ-YBXxU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/855077891054460928/JZ-YBXxU_normal.jpg',
#     'profile_link_color': '98C939',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'JR_InfoShareCoE',
#     'statuses_count': 27,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/Rd0LYbnrRE',
#     'utc_offset': -25200,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Sep 18 08:16:09 +0000 2017',
#    'entities': {'hashtags': [{'indices': [53, 66], 'text': 'LocalGovCamp'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 909692508460011521,
#    'id_str': '909692508460011521',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'Does anyone have a good Twitter list I can follow of #LocalGovCamp types? Would be great to keep up with the conversation.',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jan 24 22:20:31 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Data, civic tech, innovation and people. Occasional political "opinion". Freelance currently working for @ODIHQ.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'edparkes.co.uk',
#         'expanded_url': 'http://www.edparkes.co.uk',
#         'indices': [0, 23],
#         'url': 'https://t.co/X6VpTwzwwh'}]}},
#     'favourites_count': 899,
#     'follow_request_sent': None,
#     'followers_count': 2379,
#     'following': None,
#     'friends_count': 2562,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 242488617,
#     'id_str': '242488617',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 138,
#     'location': 'Peckham, London',
#     'name': 'Ed Parkes',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/242488617/1471972862',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/671219989475688448/g_46onR7_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/671219989475688448/g_46onR7_normal.jpg',
#     'profile_link_color': '38610B',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'edtparkes',
#     'statuses_count': 2524,
#     'time_zone': 'Dublin',
#     'translator_type': 'none',
#     'url': 'https://t.co/X6VpTwzwwh',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Sep 18 08:01:57 +0000 2017',
#    'entities': {'hashtags': [{'indices': [69, 82], 'text': 'localgovcamp'},
#      {'indices': [83, 97], 'text': 'cybersecurity'}],
#     'symbols': [],
#     'urls': [{'display_url': 'paper.li/NorfolkLassie/…',
#       'expanded_url': 'http://paper.li/NorfolkLassie/1482480126?edition_id=a3a04450-9c47-11e7-b828-0cc47a0d1609',
#       'indices': [45, 68],
#       'url': 'https://t.co/YU0VEpXMNi'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 909688932761292800,
#    'id_str': '909688932761292800',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://paper.li" rel="nofollow">Paper.li</a>',
#    'text': 'The latest The public sector scrutiny Daily! https://t.co/YU0VEpXMNi #localgovcamp #cybersecurity',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jul 02 20:35:53 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Local Government officer, promoting #Scrutiny. Passionate about #socialmedia for business. Views are my own.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'linkedin.com/in/stacycosham',
#         'expanded_url': 'http://www.linkedin.com/in/stacycosham',
#         'indices': [0, 22],
#         'url': 'http://t.co/eaJAXTJGVX'}]}},
#     'favourites_count': 1072,
#     'follow_request_sent': None,
#     'followers_count': 500,
#     'following': None,
#     'friends_count': 365,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 53179463,
#     'id_str': '53179463',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 65,
#     'location': 'Norfolk',
#     'name': 'Stacy Cosham',
#     'notifications': None,
#     'profile_background_color': 'BADFCD',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/53179463/1452202586',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/801165125633896448/YZZ0VyeM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/801165125633896448/YZZ0VyeM_normal.jpg',
#     'profile_link_color': 'AE00FF',
#     'profile_sidebar_border_color': 'F2E195',
#     'profile_sidebar_fill_color': 'FFF7CC',
#     'profile_text_color': '0C3E53',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'NorfolkLassie',
#     'statuses_count': 6561,
#     'time_zone': 'Europe/London',
#     'translator_type': 'none',
#     'url': 'http://t.co/eaJAXTJGVX',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Sep 18 06:49:35 +0000 2017',
#    'entities': {'hashtags': [{'indices': [15, 28], 'text': 'localgovcamp'},
#      {'indices': [32, 47], 'text': 'commsunplugged'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 3,
#    'favorited': False,
#    'geo': None,
#    'id': 909670719604367365,
#    'id_str': '909670719604367365',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'If you enjoyed #localgovcamp or #commsunplugged this weekend well done you. Make a small change today and every day this week. Go on.',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Dec 10 15:36:31 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Public sector PR and communication. Helps organisations communicate better. Dad. #localgov at heart. RSA Fellow. @comms2point0 and @commscamp co-founder.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'danslee.wordpress.com',
#         'expanded_url': 'http://danslee.wordpress.com/',
#         'indices': [0, 23],
#         'url': 'https://t.co/dhn7qzxlel'}]}},
#     'favourites_count': 14874,
#     'follow_request_sent': None,
#     'followers_count': 9765,
#     'following': None,
#     'friends_count': 5471,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 18021601,
#     'id_str': '18021601',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 667,
#     'location': 'West Midlands, UK.',
#     'name': 'Dan Slee',
#     'notifications': None,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/4049828/red2.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/4049828/red2.jpg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18021601/1398236239',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/486791378941124610/GIJW2jxv_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/486791378941124610/GIJW2jxv_normal.jpeg',
#     'profile_link_color': 'DE1616',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'danslee',
#     'statuses_count': 61390,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': 'https://t.co/dhn7qzxlel',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Sep 18 06:47:08 +0000 2017',
#    'entities': {'hashtags': [{'indices': [28, 41], 'text': 'localgovcamp'},
#      {'indices': [46, 57], 'text': 'oneteamgov'}],
#     'symbols': [],
#     'urls': [{'display_url': 'fb.me/2hbQTfghE',
#       'expanded_url': 'http://fb.me/2hbQTfghE',
#       'indices': [107, 130],
#       'url': 'https://t.co/pSxhFKKoOb'}],
#     'user_mentions': []},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 909670105654710272,
#    'id_str': '909670105654710272',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#    'text': "Something is happening with #localgovcamp and #oneteamgov, and it's exciting\nTurning words into actions... https://t.co/pSxhFKKoOb",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jun 10 21:06:14 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'We are a new type of consultancy dedicated to building capacity – working together to give organisations the ability to transform.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'redquadrant.com',
#         'expanded_url': 'http://www.redquadrant.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/VkpqLGuWsP'}]}},
#     'favourites_count': 111,
#     'follow_request_sent': None,
#     'followers_count': 596,
#     'following': None,
#     'friends_count': 367,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 46226031,
#     'id_str': '46226031',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 25,
#     'location': 'London, UK',
#     'name': 'RedQuadrant',
#     'notifications': None,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/769361485/b4ab829eb7af6ec0f26308b07aa332e8.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/769361485/b4ab829eb7af6ec0f26308b07aa332e8.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/46226031/1358759110',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3156568873/deb8325455b77f3daccf3e38b36b9c81_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3156568873/deb8325455b77f3daccf3e38b36b9c81_normal.jpeg',
#     'profile_link_color': '983730',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'FCF7CF',
#     'profile_text_color': 'E6E3A0',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'RedQuadrant',
#     'statuses_count': 1106,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/VkpqLGuWsP',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Sep 18 06:43:40 +0000 2017',
#    'entities': {'hashtags': [{'indices': [48, 61], 'text': 'localgovcamp'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 20424111,
#       'id_str': '20424111',
#       'indices': [3, 11],
#       'name': 'Nick Hill',
#       'screen_name': 'psfnick'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 909669231146471424,
#    'id_str': '909669231146471424',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 5,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Sep 16 19:54:07 +0000 2017',
#     'entities': {'hashtags': [{'indices': [35, 48], 'text': 'localgovcamp'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 15,
#     'favorited': False,
#     'geo': None,
#     'id': 909143379937767431,
#     'id_str': '909143379937767431',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 5,
#     'retweeted': False,
#     'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#     'text': 'Both Inspired &amp; "Ruined" after #localgovcamp. Big up City of Bristol, Sponsors, Attendees &amp; fellow organisers. Lets do it again in Spring!',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Feb 09 08:59:31 +0000 2009',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'about.me/nick_hill',
#          'expanded_url': 'http://about.me/nick_hill',
#          'indices': [0, 22],
#          'url': 'http://t.co/NhDLpYB8Ct'}]}},
#      'favourites_count': 100,
#      'follow_request_sent': None,
#      'followers_count': 1583,
#      'following': None,
#      'friends_count': 1771,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 20424111,
#      'id_str': '20424111',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 152,
#      'location': 'Peak District',
#      'name': 'Nick Hill',
#      'notifications': None,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/424184741315624960/oC15MtIo_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/424184741315624960/oC15MtIo_normal.jpeg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'psfnick',
#      'statuses_count': 7529,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'http://t.co/NhDLpYB8Ct',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'text': 'RT @psfnick: Both Inspired &amp; "Ruined" after #localgovcamp. Big up City of Bristol, Sponsors, Attendees &amp; fellow organisers. Lets do it agai…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Apr 24 13:35:02 +0000 2017',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 104,
#     'follow_request_sent': None,
#     'followers_count': 31,
#     'following': None,
#     'friends_count': 106,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 856501738593030150,
#     'id_str': '856501738593030150',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en-gb',
#     'listed_count': 1,
#     'location': 'Cheshire',
#     'name': 'Katherine Beswick',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/880779806052417536/-N77CI5r_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880779806052417536/-N77CI5r_normal.jpg',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'KBeswick71',
#     'statuses_count': 71,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -25200,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Sep 18 03:25:03 +0000 2017',
#    'entities': {'hashtags': [{'indices': [109, 122], 'text': 'localgovcamp'},
#      {'indices': [123, 134], 'text': 'salesforce'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 358692560,
#       'id_str': '358692560',
#       'indices': [3, 14],
#       'name': 'Kerry Lagan',
#       'screen_name': 'KerryLagan'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 909619250087776256,
#    'id_str': '909619250087776256',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Sep 15 09:50:38 +0000 2017',
#     'entities': {'hashtags': [{'indices': [93, 106], 'text': 'localgovcamp'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/908629119218409473',
#        'indices': [108, 131],
#        'url': 'https://t.co/mEuhJmOtOa'}],
#      'user_mentions': []},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 908629119218409473,
#     'id_str': '908629119218409473',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'What does transformation mean to local gov? Trust and transparency. People before technology #localgovcamp… https://t.co/mEuhJmOtOa',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Aug 20 10:12:14 +0000 2011',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'arts/tech/publishing, works @salesforce',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'uk.linkedin.com/pub/kerry-laga…',
#          'expanded_url': 'https://uk.linkedin.com/pub/kerry-lagan/50/91b/12',
#          'indices': [0, 23],
#          'url': 'https://t.co/FUTvln2icF'}]}},
#      'favourites_count': 86,
#      'follow_request_sent': None,
#      'followers_count': 732,
#      'following': None,
#      'friends_count': 587,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 358692560,
#      'id_str': '358692560',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 17,
#      'location': 'Dublin City, Ireland',
#      'name': 'Kerry Lagan',
#      'notifications': None,
#      'profile_background_color': 'B2DFDA',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/358692560/1466029513',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/743207755507503104/EkhBBNxt_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/743207755507503104/EkhBBNxt_normal.jpg',
#      'profile_link_color': '93A644',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'KerryLagan',
#      'statuses_count': 461,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/FUTvln2icF',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="https://www.throne.ie" rel="nofollow">Throne app </a>',
#    'text': 'RT @KerryLagan: What does transformation mean to local gov? Trust and transparency. People before technology #localgovcamp #salesforce http…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Aug 30 17:58:07 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': True,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 0,
#     'follow_request_sent': None,
#     'followers_count': 65,
#     'following': None,
#     'friends_count': 2364,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 902953591194996736,
#     'id_str': '902953591194996736',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 3,
#     'location': '',
#     'name': 'Throne',
#     'notifications': None,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Throne_ie',
#     'statuses_count': 8449,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Sep 18 03:25:03 +0000 2017',
#    'entities': {'hashtags': [{'indices': [109, 122], 'text': 'localgovcamp'},
#      {'indices': [123, 134], 'text': 'salesforce'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 358692560,
#       'id_str': '358692560',
#       'indices': [3, 14],
#       'name': 'Kerry Lagan',
#       'screen_name': 'KerryLagan'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 909619248867233793,
#    'id_str': '909619248867233793',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Sep 15 09:50:38 +0000 2017',
#     'entities': {'hashtags': [{'indices': [93, 106], 'text': 'localgovcamp'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/908629119218409473',
#        'indices': [108, 131],
#        'url': 'https://t.co/mEuhJmOtOa'}],
#      'user_mentions': []},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 908629119218409473,
#     'id_str': '908629119218409473',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'What does transformation mean to local gov? Trust and transparency. People before technology #localgovcamp… https://t.co/mEuhJmOtOa',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Aug 20 10:12:14 +0000 2011',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'arts/tech/publishing, works @salesforce',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'uk.linkedin.com/pub/kerry-laga…',
#          'expanded_url': 'https://uk.linkedin.com/pub/kerry-lagan/50/91b/12',
#          'indices': [0, 23],
#          'url': 'https://t.co/FUTvln2icF'}]}},
#      'favourites_count': 86,
#      'follow_request_sent': None,
#      'followers_count': 732,
#      'following': None,
#      'friends_count': 587,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 358692560,
#      'id_str': '358692560',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 17,
#      'location': 'Dublin City, Ireland',
#      'name': 'Kerry Lagan',
#      'notifications': None,
#      'profile_background_color': 'B2DFDA',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/358692560/1466029513',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/743207755507503104/EkhBBNxt_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/743207755507503104/EkhBBNxt_normal.jpg',
#      'profile_link_color': '93A644',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'KerryLagan',
#      'statuses_count': 461,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/FUTvln2icF',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="https://www.twitter.com/JiveLocal" rel="nofollow">JiveLocal</a>',
#    'text': 'RT @KerryLagan: What does transformation mean to local gov? Trust and transparency. People before technology #localgovcamp #salesforce http…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Nov 25 12:11:32 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Local markets, events, shops; local buy, sell, swap or give-away, at #JiveMap, we love everything local! Download free app: https://t.co/NDJReqrUdA',
#     'entities': {'description': {'urls': [{'display_url': 'bnc.lt/local',
#         'expanded_url': 'http://bnc.lt/local',
#         'indices': [124, 147],
#         'url': 'https://t.co/NDJReqrUdA'}]},
#      'url': {'urls': [{'display_url': 'jivemap.com',
#         'expanded_url': 'https://jivemap.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/fi3uhxApoe'}]}},
#     'favourites_count': 3188,
#     'follow_request_sent': None,
#     'followers_count': 17298,
#     'following': None,
#     'friends_count': 6605,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2213978251,
#     'id_str': '2213978251',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en-gb',
#     'listed_count': 3706,
#     'location': 'UK',
#     'name': 'Jive Local',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2213978251/1462405716',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/727818011609059328/VFuU07gH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/727818011609059328/VFuU07gH_normal.jpg',
#     'profile_link_color': 'F68636',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'JiveLocal',
#     'statuses_count': 30026,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/fi3uhxApoe',
#     'utc_offset': -25200,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Sep 17 23:45:08 +0000 2017',
#    'entities': {'hashtags': [{'indices': [43, 56], 'text': 'localgovcamp'},
#      {'indices': [61, 72], 'text': 'oneteamgov'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 14464195,
#       'id_str': '14464195',
#       'indices': [3, 13],
#       'name': 'BenjaminP.Taylor🇪🇺',
#       'screen_name': 'antlerboy'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 909563907026677760,
#    'id_str': '909563907026677760',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
# ...
#        'expanded_url': 'https://buff.ly/2xdk5KZ',
#        'indices': [104, 127],
#        'url': 'https://t.co/cOKPXBkLHd'}],
#      'user_mentions': []},
#     'favorite_count': 5,
#     'favorited': False,
#     'geo': None,
#     'id': 909524869188063232,
#     'id_str': '909524869188063232',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#     'text': "Something is happening with #localgovcamp and #oneteamgov, and it's exciting\nTurning words into actions https://t.co/cOKPXBkLHd",
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Apr 21 17:04:03 +0000 2008',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'https://t.co/a4WveMqgSe service evolutionary RTs and headline tweets are leaves in the wind... Come join me: https://t.co/9xdYiIjVNp',
#      'entities': {'description': {'urls': [{'display_url': 'redquadrant.com',
#          'expanded_url': 'http://www.redquadrant.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/a4WveMqgSe'},
#         {'display_url': 'bentaylor.com',
#          'expanded_url': 'http://www.bentaylor.com',
#          'indices': [109, 132],
#          'url': 'https://t.co/9xdYiIjVNp'}]},
#       'url': {'urls': [{'display_url': 'linkedin.com/in/antlerboy',
#          'expanded_url': 'http://www.linkedin.com/in/antlerboy',
#          'indices': [0, 23],
#          'url': 'https://t.co/exQsoxY708'}]}},
#      'favourites_count': 3221,
#      'follow_request_sent': None,
#      'followers_count': 7253,
#      'following': None,
#      'friends_count': 7973,
#      'geo_enabled': False,
#      'has_extended_profile': True,
#      'id': 14464195,
#      'id_str': '14464195',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en-gb',
#      'listed_count': 397,
#      'location': 'London',
#      'name': 'BenjaminP.Taylor🇪🇺',
#      'notifications': None,
#      'profile_background_color': '3E0908',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/660626917649989632/y1uohX68.jpg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/660626917649989632/y1uohX68.jpg',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14464195/1348438376',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/801216620442091520/dEdOftZG_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/801216620442091520/dEdOftZG_normal.jpg',
#      'profile_link_color': 'ED7703',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'antlerboy',
#      'statuses_count': 24810,
#      'time_zone': 'London',
#      'translator_type': 'none',
#      'url': 'https://t.co/exQsoxY708',
#      'utc_offset': 3600,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': "RT @antlerboy: Something is happening with #localgovcamp and #oneteamgov, and it's exciting\nTurning words into actions https://t.co/cOKPXBk…",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Jun 28 10:06:45 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '#localgov Digital Services Manager and #digitaltransformation Lead. Co-Chair of @LocalGovDigital. Lead for @LGMakers. @LocalGovCamp maker. @CodeClub volunteer.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'philrumens.blogspot.com',
#         'expanded_url': 'http://philrumens.blogspot.com/',
#         'indices': [0, 22],
#         'url': 'http://t.co/seOWIUKwFq'}]}},
#     'favourites_count': 682,
#     'follow_request_sent': None,
#     'followers_count': 2353,
#     'following': None,
#     'friends_count': 925,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 51696620,
#     'id_str': '51696620',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 183,
#     'location': 'West Berkshire',
#     'name': 'Phil Rumens',
#     'notifications': None,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/51696620/1442682011',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/759363547629584384/B4AxVh_N_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/759363547629584384/B4AxVh_N_normal.jpg',
#     'profile_link_color': '009966',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'PhilRumens',
#     'statuses_count': 12412,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': 'http://t.co/seOWIUKwFq',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Sep 17 21:27:58 +0000 2017',
#    'entities': {'hashtags': [{'indices': [43, 56], 'text': 'localgovcamp'},
#      {'indices': [61, 72], 'text': 'oneteamgov'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 14464195,
#       'id_str': '14464195',
#       'indices': [3, 13],
#       'name': 'BenjaminP.Taylor🇪🇺',
#       'screen_name': 'antlerboy'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 909529386197676032,
#    'id_str': '909529386197676032',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sun Sep 17 21:10:01 +0000 2017',
#     'entities': {'hashtags': [{'indices': [28, 41], 'text': 'localgovcamp'},
#       {'indices': [46, 57], 'text': 'oneteamgov'}],
#      'symbols': [],
#      'urls': [{'display_url': 'buff.ly/2xdk5KZ',
#        'expanded_url': 'https://buff.ly/2xdk5KZ',
#        'indices': [104, 127],
#        'url': 'https://t.co/cOKPXBkLHd'}],
#      'user_mentions': []},
#     'favorite_count': 5,
#     'favorited': False,
#     'geo': None,
#     'id': 909524869188063232,
#     'id_str': '909524869188063232',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#     'text': "Something is happening with #localgovcamp and #oneteamgov, and it's exciting\nTurning words into actions https://t.co/cOKPXBkLHd",
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Apr 21 17:04:03 +0000 2008',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'https://t.co/a4WveMqgSe service evolutionary RTs and headline tweets are leaves in the wind... Come join me: https://t.co/9xdYiIjVNp',
#      'entities': {'description': {'urls': [{'display_url': 'redquadrant.com',
#          'expanded_url': 'http://www.redquadrant.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/a4WveMqgSe'},
#         {'display_url': 'bentaylor.com',
#          'expanded_url': 'http://www.bentaylor.com',
#          'indices': [109, 132],
#          'url': 'https://t.co/9xdYiIjVNp'}]},
#       'url': {'urls': [{'display_url': 'linkedin.com/in/antlerboy',
#          'expanded_url': 'http://www.linkedin.com/in/antlerboy',
#          'indices': [0, 23],
#          'url': 'https://t.co/exQsoxY708'}]}},
#      'favourites_count': 3221,
#      'follow_request_sent': None,
#      'followers_count': 7253,
#      'following': None,
#      'friends_count': 7973,
#      'geo_enabled': False,
#      'has_extended_profile': True,
#      'id': 14464195,
#      'id_str': '14464195',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en-gb',
#      'listed_count': 397,
#      'location': 'London',
#      'name': 'BenjaminP.Taylor🇪🇺',
#      'notifications': None,
#      'profile_background_color': '3E0908',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/660626917649989632/y1uohX68.jpg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/660626917649989632/y1uohX68.jpg',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14464195/1348438376',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/801216620442091520/dEdOftZG_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/801216620442091520/dEdOftZG_normal.jpg',
#      'profile_link_color': 'ED7703',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'antlerboy',
#      'statuses_count': 24810,
#      'time_zone': 'London',
#      'translator_type': 'none',
#      'url': 'https://t.co/exQsoxY708',
#      'utc_offset': 3600,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "RT @antlerboy: Something is happening with #localgovcamp and #oneteamgov, and it's exciting\nTurning words into actions https://t.co/cOKPXBk…",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Oct 26 14:32:20 +0000 2014',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Lead User Researcher Freelance. Ex DWP & UR at DWP Digital UC + Design Research Manager at Scottish Enterprise. Currently working in government in Scotland.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 11241,
#     'follow_request_sent': None,
#     'followers_count': 1034,
#     'following': None,
#     'friends_count': 1084,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 2845221183,
#     'id_str': '2845221183',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en-GB',
#     'listed_count': 109,
#     'location': 'Was London. Now Scotland.',
#     'name': 'Smile :)',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2845221183/1501950030',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/893869320727605250/9xci_eOw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/893869320727605250/9xci_eOw_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'janereid73',
#     'statuses_count': 7376,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Sep 17 21:10:01 +0000 2017',
#    'entities': {'hashtags': [{'indices': [28, 41], 'text': 'localgovcamp'},
#      {'indices': [46, 57], 'text': 'oneteamgov'}],
#     'symbols': [],
#     'urls': [{'display_url': 'buff.ly/2xdk5KZ',
#       'expanded_url': 'https://buff.ly/2xdk5KZ',
#       'indices': [104, 127],
#       'url': 'https://t.co/cOKPXBkLHd'}],
#     'user_mentions': []},
#    'favorite_count': 5,
#    'favorited': False,
#    'geo': None,
#    'id': 909524869188063232,
#    'id_str': '909524869188063232',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#    'text': "Something is happening with #localgovcamp and #oneteamgov, and it's exciting\nTurning words into actions https://t.co/cOKPXBkLHd",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Apr 21 17:04:03 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'https://t.co/a4WveMqgSe service evolutionary RTs and headline tweets are leaves in the wind... Come join me: https://t.co/9xdYiIjVNp',
#     'entities': {'description': {'urls': [{'display_url': 'redquadrant.com',
#         'expanded_url': 'http://www.redquadrant.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/a4WveMqgSe'},
#        {'display_url': 'bentaylor.com',
#         'expanded_url': 'http://www.bentaylor.com',
#         'indices': [109, 132],
#         'url': 'https://t.co/9xdYiIjVNp'}]},
#      'url': {'urls': [{'display_url': 'linkedin.com/in/antlerboy',
#         'expanded_url': 'http://www.linkedin.com/in/antlerboy',
#         'indices': [0, 23],
#         'url': 'https://t.co/exQsoxY708'}]}},
#     'favourites_count': 3221,
#     'follow_request_sent': None,
#     'followers_count': 7253,
#     'following': None,
#     'friends_count': 7973,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 14464195,
#     'id_str': '14464195',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en-gb',
#     'listed_count': 397,
#     'location': 'London',
#     'name': 'BenjaminP.Taylor🇪🇺',
#     'notifications': None,
#     'profile_background_color': '3E0908',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/660626917649989632/y1uohX68.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/660626917649989632/y1uohX68.jpg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14464195/1348438376',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/801216620442091520/dEdOftZG_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/801216620442091520/dEdOftZG_normal.jpg',
#     'profile_link_color': 'ED7703',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'antlerboy',
#     'statuses_count': 24810,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': 'https://t.co/exQsoxY708',
#     'utc_offset': 3600,
#     'verified': False}}]}

# %%
twitter.search(q='LocalGovCamp', result_type='popular')
# Out:
# {'search_metadata': {'completed_in': 0.077,
#   'count': 15,
#   'max_id': 0,
#   'max_id_str': '0',
#   'query': 'LocalGovCamp',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': []}
